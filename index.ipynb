# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
import sqlite3
import pandas as pd
connection = sqlite3.connect('data.sqlite')
cursor = connection.cursor()

# %%
#Your code here
# cursor.execute('''SELECT * FROM employees''').fetchall()
cursor.execute('''SELECT * FROM employees e JOIN offices o using (officeCode)''').fetchall()
# Out:
# [('1002',
#   'Murphy',
#   'Diane',
#   'x5800',
#   'dmurphy@classicmodelcars.com',
#   '1',
#   '',
#   'President',
#   'San Francisco',
#   '+1 650 219 4782',
#   '100 Market Street',
#   'Suite 300',
#   'CA',
#   'USA',
#   '94080',
#   'NA'),
#  ('1056',
#   'Patterson',
#   'Mary',
#   'x4611',
#   'mpatterso@classicmodelcars.com',
#   '1',
#   '1002',
#   'VP Sales',
#   'San Francisco',
#   '+1 650 219 4782',
#   '100 Market Street',
#   'Suite 300',
#   'CA',
#   'USA',
#   '94080',
#   'NA'),
#  ('1076',
#   'Firrelli',
#   'Jeff',
#   'x9273',
#   'jfirrelli@classicmodelcars.com',
#   '1',
#   '1002',
#   'VP Marketing',
#   'San Francisco',
#   '+1 650 219 4782',
#   '100 Market Street',
#   'Suite 300',
#   'CA',
#   'USA',
#   '94080',
#   'NA'),
#  ('1088',
#   'Patterson',
#   'William',
#   'x4871',
#   'wpatterson@classicmodelcars.com',
#   '6',
#   '1056',
#   'Sales Manager (APAC)',
#   'Sydney',
#   '+61 2 9264 2451',
#   '5-11 Wentworth Avenue',
# ...

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
cursor.execute('''SELECT cu.customerName, o.orderNumber, o.orderDate, o.status FROM orders o, customers cu JOIN customers c using (customerNumber)''').fetchall()
# Out:
# [('Atelier graphique', '10100', '2003-01-06', 'Shipped'),
#  ('Signal Gift Stores', '10100', '2003-01-06', 'Shipped'),
#  ('Australian Collectors, Co.', '10100', '2003-01-06', 'Shipped'),
#  ('La Rochelle Gifts', '10100', '2003-01-06', 'Shipped'),
#  ('Baane Mini Imports', '10100', '2003-01-06', 'Shipped'),
#  ('Mini Gifts Distributors Ltd.', '10100', '2003-01-06', 'Shipped'),
#  ('Havel & Zbyszek Co', '10100', '2003-01-06', 'Shipped'),
#  ('Blauer See Auto, Co.', '10100', '2003-01-06', 'Shipped'),
#  ('Mini Wheels Co.', '10100', '2003-01-06', 'Shipped'),
#  ('Land of Toys Inc.', '10100', '2003-01-06', 'Shipped'),
#  ('Euro+ Shopping Channel', '10100', '2003-01-06', 'Shipped'),
#  ('Volvo Model Replicas, Co', '10100', '2003-01-06', 'Shipped'),
#  ('Danish Wholesale Imports', '10100', '2003-01-06', 'Shipped'),
#  ('Saveley & Henriot, Co.', '10100', '2003-01-06', 'Shipped'),
#  ('Dragon Souveniers, Ltd.', '10100', '2003-01-06', 'Shipped'),
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
cursor.execute('''SELECT * FROM orders JOIN orderdetails using (orderNumber)''').fetchall()
# Out:
# [('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S18_1749',
#   '30',
#   '136.00',
#   '3'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S18_2248',
#   '50',
#   '55.09',
#   '2'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S18_4409',
#   '22',
#   '75.46',
#   '4'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S24_3969',
#   '49',
#   '35.29',
#   '1'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
#   '2003-01-11',
#   'Shipped',
#   'Check on availability.',
#   '128',
#   'S18_2325',
#   '25',
#   '108.06',
#   '4'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
#   '2003-01-11',
#   'Shipped',
#   'Check on availability.',
#   '128',
#   'S18_2795',
#   '26',
#   '167.06',
#   '1'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and all the product information for each product in the order.

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
